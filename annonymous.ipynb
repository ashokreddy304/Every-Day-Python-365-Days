# %%
l = [1,2,3,4]
t = (5,6,7,8)
print(l + t)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 l = [1,2,3,4]
#       2 t = (5,6,7,8)
# ----> 3 print(l + t)
#
# TypeError: can only concatenate list (not "tuple") to list

# %%
l = [1,2,3,4]
t = (5,6,7,8)
print(l + list(t))
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]
